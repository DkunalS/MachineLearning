# %%
from sklearn.pipeline import Pipeline

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import make_column_selector, make_column_transformer
from sklearn.ensemble import GradientBoostingClassifier, StackingClassifier, RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, r2_score, roc_auc_score, log_loss
from sklearn.model_selection import GridSearchCV, KFold, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
import warnings
warnings.filterwarnings('ignore')

# %%
cancer = pd.read_csv('BreastCancer.csv',index_col=0)
cancer
# Out:
#           Clump  UniCell_Size  Uni_CellShape  MargAdh  SEpith  BareN  \
# Code
# 61634         5             4              3        1       2      2
# 63375         9             1              2        6       4     10
# 76389        10             4              7        2       2      8
# 95719         6            10             10       10       8     10
# 128059        1             1              1        1       2      5
# ...         ...           ...            ...      ...     ...    ...
# 1369821      10            10             10       10       5     10
# 1371026       5            10             10       10       4     10
# 1371920       5             1              1        1       2      1
# 8233704       4             1              1        1       1      1
# 13454352      1             1              3        1       2      1
#
#           BChromatin  NoemN  Mitoses      Class
# Code
# 61634              2      3        1     Benign
# 63375              7      7        2  Malignant
# 76389              6      1        1  Malignant
# 95719              7     10        7  Malignant
# 128059             5      1        1     Benign
# ...              ...    ...      ...        ...
# 1369821           10     10        7  Malignant
# 1371026            5      6        3  Malignant
# 1371920            3      2        1     Benign
# 8233704            2      1        1     Benign
# 13454352           2      1        1     Benign
#
# [699 rows x 10 columns]

# %%
X = cancer.drop(columns='Class')
y = cancer.Class

# %%
knn = KNeighborsClassifier()
dtc = DecisionTreeClassifier(random_state=24)
svm = SVC(probability=True, random_state=24)
nb = GaussianNB()
rf = RandomForestClassifier(random_state=24)
kfold = StratifiedKFold(n_splits=5, shuffle=True,random_state=24)

stack = StackingClassifier(estimators=[('dtc',dtc),('svm',svm),('knn',knn),('nb',nb)],final_estimator=rf)
stack.get_params()
# Out:
# {'cv': None,
#  'estimators': [('dtc', DecisionTreeClassifier(random_state=24)),
#   ('svm', SVC(probability=True, random_state=24)),
#   ('knn', KNeighborsClassifier()),
#   ('nb', GaussianNB())],
#  'final_estimator__bootstrap': True,
#  'final_estimator__ccp_alpha': 0.0,
#  'final_estimator__class_weight': None,
#  'final_estimator__criterion': 'gini',
#  'final_estimator__max_depth': None,
#  'final_estimator__max_features': 'sqrt',
#  'final_estimator__max_leaf_nodes': None,
#  'final_estimator__max_samples': None,
#  'final_estimator__min_impurity_decrease': 0.0,
#  'final_estimator__min_samples_leaf': 1,
#  'final_estimator__min_samples_split': 2,
#  'final_estimator__min_weight_fraction_leaf': 0.0,
#  'final_estimator__monotonic_cst': None,
#  'final_estimator__n_estimators': 100,
#  'final_estimator__n_jobs': None,
#  'final_estimator__oob_score': False,
#  'final_estimator__random_state': 24,
#  'final_estimator__verbose': 0,
#  'final_estimator__warm_start': False,
#  'final_estimator': RandomForestClassifier(random_state=24),
#  'n_jobs': None,
#  'passthrough': False,
#  'stack_method': 'auto',
#  'verbose': 0,
#  'dtc': DecisionTreeClassifier(random_state=24),
#  'svm': SVC(probability=True, random_state=24),
#  'knn': KNeighborsClassifier(),
#  'nb': GaussianNB(),
#  'dtc__ccp_alpha': 0.0,
#  'dtc__class_weight': None,
#  'dtc__criterion': 'gini',
#  'dtc__max_depth': None,
#  'dtc__max_features': None,
#  'dtc__max_leaf_nodes': None,
#  'dtc__min_impurity_decrease': 0.0,
#  'dtc__min_samples_leaf': 1,
#  'dtc__min_samples_split': 2,
#  'dtc__min_weight_fraction_leaf': 0.0,
#  'dtc__monotonic_cst': None,
#  'dtc__random_state': 24,
#  'dtc__splitter': 'best',
#  'svm__C': 1.0,
#  'svm__break_ties': False,
#  'svm__cache_size': 200,
#  'svm__class_weight': None,
#  'svm__coef0': 0.0,
#  'svm__decision_function_shape': 'ovr',
#  'svm__degree': 3,
#  'svm__gamma': 'scale',
#  'svm__kernel': 'rbf',
#  'svm__max_iter': -1,
#  'svm__probability': True,
#  'svm__random_state': 24,
#  'svm__shrinking': True,
#  'svm__tol': 0.001,
#  'svm__verbose': False,
#  'knn__algorithm': 'auto',
#  'knn__leaf_size': 30,
#  'knn__metric': 'minkowski',
#  'knn__metric_params': None,
#  'knn__n_jobs': None,
#  'knn__n_neighbors': 5,
#  'knn__p': 2,
#  'knn__weights': 'uniform',
#  'nb__priors': None,
#  'nb__var_smoothing': 1e-09}

# %%
params = {'dtc__max_depth':[None],
          'final_estimator__max_depth': [None],
          'passthrough':[True,False],
          'svm__C': np.linspace(0.001,3,5),
          'knn__n_neighbors':[5,10]}
gcv = GridSearchCV(stack, param_grid=params, cv=kfold, scoring='neg_log_loss', verbose=3)
gcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=0.001;, score=-0.050 total time=   0.5s
# [CV 2/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=0.001;, score=-0.325 total time=   0.5s
# [CV 3/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=0.001;, score=-0.079 total time=   0.5s
# [CV 4/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=0.001;, score=-0.361 total time=   0.5s
# [CV 5/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=0.001;, score=-0.111 total time=   0.4s
# [CV 1/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=0.75075;, score=-0.058 total time=   0.3s
# [CV 2/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=0.75075;, score=-0.323 total time=   0.3s
# [CV 3/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=0.75075;, score=-0.075 total time=   0.3s
# [CV 4/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=0.75075;, score=-0.136 total time=   0.2s
# [CV 5/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=0.75075;, score=-0.109 total time=   0.3s
# [CV 1/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=1.5005;, score=-0.059 total time=   0.3s
# [CV 2/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=1.5005;, score=-0.320 total time=   0.3s
# [CV 3/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=1.5005;, score=-0.074 total time=   0.3s
# [CV 4/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=1.5005;, score=-0.138 total time=   0.3s
# [CV 5/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=1.5005;, score=-0.103 total time=   0.3s
# [CV 1/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=2.25025;, score=-0.059 total time=   0.3s
# [CV 2/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=2.25025;, score=-0.322 total time=   0.3s
# [CV 3/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=2.25025;, score=-0.077 total time=   0.3s
# [CV 4/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=2.25025;, score=-0.363 total time=   0.2s
# [CV 5/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=2.25025;, score=-0.099 total time=   0.3s
# [CV 1/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=3.0;, score=-0.054 total time=   0.3s
# [CV 2/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=3.0;, score=-0.322 total time=   0.2s
# [CV 3/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=3.0;, score=-0.079 total time=   0.3s
# [CV 4/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=3.0;, score=-0.135 total time=   0.3s
# [CV 5/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=True, svm__C=3.0;, score=-0.105 total time=   0.3s
# [CV 1/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=False, svm__C=0.001;, score=-0.056 total time=   0.4s
# [CV 2/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=False, svm__C=0.001;, score=-0.351 total time=   0.4s
# [CV 3/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=False, svm__C=0.001;, score=-0.319 total time=   0.4s
# [CV 4/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=False, svm__C=0.001;, score=-0.636 total time=   0.4s
# [CV 5/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=False, svm__C=0.001;, score=-0.566 total time=   0.4s
# [CV 1/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=False, svm__C=0.75075;, score=-0.341 total time=   0.2s
# [CV 2/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=False, svm__C=0.75075;, score=-0.377 total time=   0.2s
# [CV 3/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=False, svm__C=0.75075;, score=-0.321 total time=   0.3s
# [CV 4/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=False, svm__C=0.75075;, score=-1.112 total time=   0.2s
# [CV 5/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=False, svm__C=0.75075;, score=-0.344 total time=   0.2s
# [CV 1/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=False, svm__C=1.5005;, score=-0.327 total time=   0.3s
# [CV 2/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=False, svm__C=1.5005;, score=-0.344 total time=   0.3s
# [CV 3/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=False, svm__C=1.5005;, score=-0.300 total time=   0.3s
# [CV 4/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=False, svm__C=1.5005;, score=-0.640 total time=   0.2s
# [CV 5/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=False, svm__C=1.5005;, score=-0.077 total time=   0.3s
# [CV 1/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=False, svm__C=2.25025;, score=-0.313 total time=   0.2s
# [CV 2/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=False, svm__C=2.25025;, score=-0.348 total time=   0.2s
# [CV 3/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=False, svm__C=2.25025;, score=-0.069 total time=   0.2s
# [CV 4/5] END dtc__max_depth=None, final_estimator__max_depth=None, knn__n_neighbors=5, passthrough=False, svm__C

# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=24, shuffle=True),
#              estimator=StackingClassifier(estimators=[('dtc',
#                                                        DecisionTreeClassifier(random_state=24)),
#                                                       ('svm',
#                                                        SVC(probability=True,
#                                                            random_state=24)),
#                                                       ('knn',
#                                                        KNeighborsClassifier()),
#                                                       ('nb', GaussianNB())],
#                                           final_estimator=RandomForestClassifier(random_state=24)),
#              param_grid={'dtc__max_depth': [None],
#                          'final_estimator__max_depth': [None],
#                          'knn__n_neighbors': [5, 10],
#                          'passthrough': [True, False],
#                          'svm__C': array([1.00000e-03, 7.50750e-01, 1.50050e+00, 2.25025e+00, 3.00000e+00])},
#              scoring='neg_log_loss', verbose=3)

# %%
print("Best score: ",gcv.best_params_)
print("Best Score: ", gcv.best_score_)
# Out:
# Best score:  {'dtc__max_depth': None, 'final_estimator__max_depth': None, 'knn__n_neighbors': 10, 'passthrough': True, 'svm__C': 1.5005}
# Best Score:  -0.09394181561687927

# %%
best_stack = gcv.best_estimator_

# %%
import pickle
pkfile = open('stack_cancer.pkl','wb')
pickle.dump(best_stack,pkfile)

# %%
infile = open('stack_cancer.pkl','rb')
objLoad = pickle.load(infile)
objLoad
# Out:
# StackingClassifier(estimators=[('dtc', DecisionTreeClassifier(random_state=24)),
#                                ('svm',
#                                 SVC(C=1.5005, probability=True,
#                                     random_state=24)),
#                                ('knn', KNeighborsClassifier(n_neighbors=10)),
#                                ('nb', GaussianNB())],
#                    final_estimator=RandomForestClassifier(random_state=24),
#                    passthrough=True)

# %%
# tst_sat = pd.read_csv('tst_satellite.csv')
# tst_sat

# %%
# tst_sat['pred_type'] = objLoad.predict(tst_sat)

# %%
# tst_sat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 tst_sat
#
# NameError: name 'tst_sat' is not defined

# %% [markdown]
# # Gradio

# %%
import gradio as gr
import pickle
#import numpy as np 
import pandas as pd 
import os 
os.chdir('C:/Users/DAI.STUDENTSDC/Desktop/ /Machine Learning/Day 11')

def predict(Clump, UniCell_Size, Uni_CellShape, MargAdh, SEpith, BareN, BChromatin, NoemN, Mitoses):
    tst = pd.DataFrame([[Clump, UniCell_Size, Uni_CellShape, MargAdh, SEpith, BareN, BChromatin, NoemN, Mitoses]],
          columns=['Clump', 'UniCell_Size', 'Uni_CellShape', 'MargAdh', 'SEpith', 'BareN', 'BChromatin', 'NoemN', 'Mitoses'])    
    filehandler = open("stack_cancer.pkl", "rb")
    bm_loaded = pickle.load(filehandler)
    print(tst)
    return bm_loaded.predict(tst)[0] 
      

# demo = gr.Interface(
#     fn=predict,
#     inputs=["number"] * 9,
#     outputs=["text"]
# )

with gr.Blocks() as demo:
    with gr.Row():
      RI = gr.Number(label='Clump')
      Na = gr.Number(label='UniCell_Size')
      Mg = gr.Number(label='Uni_CellShape')
    with gr.Row():
      Al = gr.Number(label='MargAdh')
      Si = gr.Number(label='SEpith')
      K = gr.Number(label='BareN')
    with gr.Row():
      Ca = gr.Number(label='BChromatin')
      Ba = gr.Number(label='NoemN')
      Fe = gr.Number(label='Mitoses')
    with gr.Row(): 
      Type = gr.Text(label='Cancer Type') 
    with gr.Row():  
      button = gr.Button(value="Cancer Type?")
      button.click(predict,
            inputs=[RI, Na, Mg, Al, Si, K, Ca, Ba, Fe],
            outputs=[Type])
demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
#    Clump  UniCell_Size  Uni_CellShape  MargAdh  SEpith  BareN  BChromatin  \
# 0      5             4              3        1       2      2           2
#
#    NoemN  Mitoses
# 0      3        1
